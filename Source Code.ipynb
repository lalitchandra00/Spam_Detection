# %%
import pandas as pd

# %%
df = pd.read_csv("Data.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df = df.drop_duplicates(keep = "first")

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df['Category'] = df['Category'].map({
'ham' : 1, 'spam' : 0
})

# %%
df.head()
# Out:
#    Category                                            Message
# 0         1  Go until jurong point, crazy.. Available only ...
# 1         1                      Ok lar... Joking wif u oni...
# 2         0  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         1  U dun say so early hor... U c already then say...
# 4         1  Nah I don't think he goes to usf, he lives aro...

# %%
X = df.loc[:,'Message']

# %%
X.head()
# Out:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: Message, dtype: object

# %%
Y = df.loc[:,'Category']

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Category, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,random_state = 0)

# %%
X_train
# Out:
# 922     On ma way to school. Can you pls send me ashle...
# 3012                Hm good morning, headache anyone? :-)
# 248                       Kallis wont bat in 2nd innings.
# 5034    * Was really good to see you the other day dud...
# 612     Its a valentine game. . . Send dis msg to all ...
#                               ...
# 5320                 But we havent got da topic yet rite?
# 3462    K.. I yan jiu liao... Sat we can go 4 bugis vi...
# 1711    (No promises on when though, haven't even gott...
# 2735     Can you do a mag meeting this avo at some point?
# 2877    Fuck cedar key and fuck her (come over anyway ...
# Name: Message, Length: 4641, dtype: object

# %%
Y_test
# Out:
# 1512    1
# 4824    1
# 2983    1
# 2133    0
# 1903    1
#        ..
# 740     1
# 471     0
# 1462    1
# 4227    1
# 3622    1
# Name: Category, Length: 516, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
X_train_vec
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 60843 stored elements and shape (4641, 8152)>

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_vec,Y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,Y_pred)
# Out:
# 0.9709302325581395

# %%
new_email = input(str("Enter your mail : "))
new_email_vec = vectorizer.transform([new_email])
ans = model.predict(new_email_vec)
if ans == 1:
    print("It is not a spam mail")
else :
    print("It is a spam mail")
# Out:
# Enter your mail :  This is the 2nd time we have tried to contact u. U have won the $4800 prize. 2 claim is easy, just call 0870
# It is a spam mail
